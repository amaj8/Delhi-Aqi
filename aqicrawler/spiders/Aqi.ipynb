# %%
# !pip3 install pandas
import pandas as pd
import json
import numpy as np
# Out:
# Collecting pandas
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/a7/f7/2adca20a7fa71b6a32f823bbd83992adeceab1d8bf72992bb7a55c69c19a/pandas-1.1.0-cp36-cp36m-manylinux1_x86_64.whl (10.5MB)
#     100% |████████████████████████████████| 10.5MB 118kB/s ta 0:00:01
# Collecting python-dateutil>=2.7.3 (from pandas)
#   Using cached https://files.pythonhosted.org/packages/d4/70/d60450c3dd48ef87586924207ae8907090de0b306af2bce5d134d78615cb/python_dateutil-2.8.1-py2.py3-none-any.whl
# Collecting numpy>=1.15.4 (from pandas)
#   Using cached https://files.pythonhosted.org/packages/22/e7/4b2bdddb99f5f631d8c1de259897c2b7d65dcfcc1e0a6fd17a7f62923500/numpy-1.19.1-cp36-cp36m-manylinux1_x86_64.whl
# Collecting pytz>=2017.2 (from pandas)
#   Using cached https://files.pythonhosted.org/packages/4f/a4/879454d49688e2fad93e59d7d4efda580b783c745fd2ec2a3adf87b0808d/pytz-2020.1-py2.py3-none-any.whl
# Collecting six>=1.5 (from python-dateutil>=2.7.3->pandas)
#   Using cached https://files.pythonhosted.org/packages/ee/ff/48bde5c0f013094d729fe4b0316ba2a24774b3ff1c52d924a8a4cb04078a/six-1.15.0-py2.py3-none-any.whl
# Installing collected packages: six, python-dateutil, numpy, pytz, pandas
# Successfully installed numpy-1.19.1 pandas-1.1.0 python-dateutil-2.8.1 pytz-2020.1 six-1.15.0
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-27b9f3a4acd7> in <module>()
#       1 get_ipython().system(u'pip3 install pandas')
# ----> 2 import pandas as pd
#       3 import json
#       4 import numpy as np
#
# ImportError: No module named pandas

# %%
data = json.load(open('changed_pollutants2'))

# %%
df = pd.DataFrame(data)
df
# Out:
#       CO_avg CO_max CO_min        Date NH3_avg NH3_max NH3_min NO2_avg  \
# 0                 -      -  08/03/2020       5       4       7      45
# 1         41     30     55  08/03/2020       5       4       6      40
# 2         48     30     55  08/03/2020       5       4       6      41
# 3                 -      -  08/03/2020       5       4       6      41
# 4                 -      -  08/03/2020       5       4       7      46
# 5                 -      -  08/03/2020       5       4       7      46
# 6         92     75    124  08/03/2020       6       5       9      69
# 7        100     40    109  08/03/2020       2       5       6
# 8        101     57    109  08/03/2020       3       5       6
# 9        105     70    124  08/03/2020       4       5       7
# 10       112     70    124  08/03/2020       6       5       9      62
# 11       106     90    124  08/03/2020       7       5       9      70
# 12        18      5    104  08/03/2020       7       5       9      55
# 13        63      5    104  08/03/2020       6       4       7      45
# 14        83      5    104  08/03/2020       6       4       8      46
# 15        78     20    104  08/03/2020       7       5       9      47
# 16        59      5    104  08/03/2020       7       6       9      57
# 17        49      5    104  08/03/2020       7       5       9      56
# 18        96     91    105  08/03/2020     NaN     NaN     NaN      22
# 19        96     90    104  08/03/2020     NaN     NaN     NaN      21
# 20       102     90    105  08/03/2020     NaN     NaN     NaN      22
# 21       104     90    105  08/03/2020     NaN     NaN     NaN      22
# 22       103     90    105  08/03/2020     NaN     NaN     NaN      23
# 23       100     90    105  08/03/2020     NaN     NaN     NaN      23
# 24        38     25     80  08/03/2020      10       9      12      47
# 25        52     35     80  08/03/2020      11      10      12      47
# 26        60     35     80  08/03/2020      11      10      12      47
# 27        62     35     80  08/03/2020      11       9      12      47
# 28        66     35     80  08/03/2020      11       9      12      50
# 29        54     27     80  08/03/2020      11       9      12      48
# ...      ...    ...    ...         ...     ...     ...     ...     ...
# 32370      8      4     19  21/05/2020       3       1       5      42
# 32371     11      4     27  21/05/2020       2       1       3      59
# 32372     14      4     27  21/05/2020       2       1       3      50
# 32373     13      4     21  21/05/2020       2       1       3      45
# 32374     14      4     19  21/05/2020       2       1       3      44
# 32375     12      6     19  21/05/2020       2       1       3      43
# 32376     71     65     90  21/05/2020      11       9      12      42
# 32377     80     70     97  21/05/2020      11      10      13      46
# 32378     84     70     97  21/05/2020      11      10      13      44
# 32379     82     70     90  21/05/2020      11      10      12      42
# 32380     81     70     90  21/05/2020      11      10      12      41
# 32381     76     68     90  21/05/2020      11      10      12      41
# 32382     18     15     43  21/05/2020               -       -
# 32383     24     10     55  21/05/2020               -       -
# 32384     26     10     55  21/05/2020               -       -
# 32385     30     10     43  21/05/2020       6       5       7      22
# 32386     29     10     43  21/05/2020       6       5       7      20
# 32387     22     10     43  21/05/2020               -       -
# 32388     71     65    100  21/05/2020       5       4       7      47
# 32389     81     65    101  21/05/2020       6       5       7      53
# 32390     86     65    100  21/05/2020       6       5       7      48
# 32391     78     65    100  21/05/2020       6       5       7      46
# 32392     77     65    100  21/05/2020       6       5       7      45
# 32393     72     65    100  21/05/2020       6       4       7      45
# 32394     73     57    102  21/05/2020               -       -
# 32395     84     50    103  21/05/2020       7       6       8      49
# 32396    101     62    103  21/05/2020               -       -
# 32397     72     62    103  21/05/2020               -       -
# 32398     72     62    103  21/05/2020               -       -
# 32399     73     57    103  21/05/2020               -       -
#
#       NO2_max NO2_min  ... PM2.5_min  \
# 0          29      76  ...       314
# 1          30      64  ...       163
# 2          30      64  ...       163
# 3          30      64  ...       163
# 4          30      76  ...       260
# 5          29      76  ...       314
# 6          22     116  ...       404
# 7           -       -  ...       220
# 8           -       -  ...       220
# 9           -       -  ...       375
# 10         22     116  ...       404
# 11         22     116  ...       404
# 12         25     117  ...       NaN
# 13         17     101  ...       NaN
# 14         21     101  ...       NaN
# 15         21     101  ...       NaN
# 16         29     117  ...       NaN
# 17         26     117  ...       NaN
# 18         15      34  ...       213
# 19         16      34  ...       183
# 20         16      34  ...       183
# 21         16      34  ...       183
# 22         16      34  ...       213
# 23         16      34  ...       213
# 24         20      93  ...       318
# 25         24      92  ...       314
# 26         24      92  ...       314
# 27         24      92  ...       314
# 28         24      92  ...       318
# 29         20      92  ...       318
# ...       ...     ...  ...       ...
# 32370      21     103  ...       248
# 32371      22     103  ...       317
# 32372      22     103  ...       317
# 32373      22     103  ...       252
# 32374      22     103  ...       248
# 32375      21     103  ...       248
# 32376      30      64  ...       193
# 32377      30      81  ...       297
# 32378      30      80  ...       297
# 32379      30      64  ...       187
# 32380      30      64  ...       193
# 32381      30      64  ...       193
# 32382       -       -  ...         -
# 32383       -       -  ...         -
# 32384       -       -  ...         -
# 32385      14      31  ...       120
# 32386      13      31  ...       290
# 32387       -       -  ...       290
# 32388      25      98  ...       157
# 32389      25      98  ...       309
# 32390      25      98  ...       217
# 32391      25      98  ...       157
# 32392      25      98  ...       157
# 32393      25      98  ...       157
# 32394       -       -  ...         -
# 32395      41      67  ...       351
# 32396       -       -  ...         -
# 32397       -       -  ...         -
# 32398       -       -  ...         -
# 32399       -       -  ...         -
#
#                                               Pollutants SO2_avg SO2_max  \
# 0      [[PM2.5, 117, 32, 314], [PM10, 86, 29, 178], [...      13       4
# 1      [[PM2.5, 72, 22, 163], [PM10, 66, 14, 126], [N...      14      10
# 2      [[PM2.5, 83, 27, 163], [PM10, 76, 24, 126], [N...      14      10
# 3      [[PM2.5, 92, 30, 163], [PM10, 82, 31, 126], [N...      12       4
# 4      [[PM2.5, 115, 58, 260], [PM10, 92, 53, 141], [...      11       4
# 5      [[PM2.5, 126, 63, 314], [PM10, 96, 50, 178], [...      12       4
# 6      [[PM2.5, 204, 47, 404], [PM10, 192, 107, 358],...      14       7
# 7      [[PM2.5, 75, 18, 220], [PM10, 85, 18, 193], [N...      10       7
# 8      [[PM2.5, 96, 18, 220], [PM10, 102, 18, 193], [...      11       8
# 9      [[PM2.5, 149, 23, 375], [PM10, 143, 48, 311], ...      13       9
# 10     [[PM2.5, 199, 75, 404], [PM10, 178, 83, 358], ...      14       9
# 11     [[PM2.5, 220, 75, 404], [PM10, 197, 101, 358],...      15       9
# 12     [[PM10, 155, 52, 267], [NO2, 55, 25, 117], [NH...      19      13
# 13     [[PM10, 79, 16, 193], [NO2, 45, 17, 101], [NH3...      17      12
# 14     [[PM10, 101, 16, 222], [NO2, 46, 21, 101], [NH...      17      12
# 15     [[PM10, 131, 30, 222], [NO2, 47, 21, 101], [NH...      17      13
# 16     [[PM10, 161, 64, 267], [NO2, 57, 29, 117], [NH...      19      13
# 17     [[PM10, 163, 80, 267], [NO2, 56, 26, 117], [NH...      19      13
# 18     [[PM2.5, 92, 4, 213], [PM10, 81, 22, 132], [NO...     NaN     NaN
# 19     [[PM2.5, 62, 2, 183], [PM10, 56, 8, 132], [NO2...     NaN     NaN
# 20     [[PM2.5, 75, 2, 183], [PM10, 70, 8, 132], [NO2...     NaN     NaN
# 21     [[PM2.5, 84, 11, 183], [PM10, 79, 27, 132], [N...     NaN     NaN
# 22     [[PM2.5, 95, 26, 213], [PM10, 85, 27, 132], [N...     NaN     NaN
# 23     [[PM2.5, 96, 15, 213], [PM10, 85, 27, 132], [N...     NaN     NaN
# 24     [[PM2.5, 181, 58, 318], [PM10, 124, 78, 207], ...      20      17
# 25     [[PM2.5, 153, 42, 314], [PM10, 111, 30, 207], ...      19      16
# 26     [[PM2.5, 172, 52, 314], [PM10, 122, 41, 207], ...      18      16
# 27     [[PM2.5, 173, 52, 314], [PM10, 120, 41, 207], ...      18      16
# 28     [[PM2.5, 196, 75, 318], [PM10, 129, 70, 207], ...      18      16
# 29     [[PM2.5, 197, 77, 318], [PM10, 130, 78, 207], ...      19      17
# ...                                                  ...     ...     ...
# 32370  [[PM2.5, 77, 28, 248], [PM10, 125, 106, 175], ...      14       6
# 32371  [[PM2.5, 108, 35, 317], [PM10, 124, 96, 186], ...      14       5
# 32372  [[PM2.5, 104, 35, 317], [PM10, 125, 96, 186], ...      14       5
# 32373  [[PM2.5, 78, 35, 252], [PM10, 119, 96, 186], [...      14       5
# 32374  [[PM2.5, 81, 35, 248], [PM10, 121, 96, 175], [...      14       5
# 32375  [[PM2.5, 78, 33, 248], [PM10, 123, 96, 175], [...      14       5
# 32376  [[PM2.5, 82, 23, 193], [PM10, 143, 116, 186], ...     NaN     NaN
# 32377  [[PM2.5, 119, 32, 297], [PM10, 138, 91, 186], ...     NaN     NaN
# 32378  [[PM2.5, 112, 32, 297], [PM10, 137, 91, 186], ...     NaN     NaN
# 32379  [[PM2.5, 85, 32, 187], [PM10, 133, 91, 186], [...     NaN     NaN
# 32380  [[PM2.5, 83, 32, 193], [PM10, 135, 91, 186], [...     NaN     NaN
# 32381  [[PM2.5, 84, 32, 193], [PM10, 141, 105, 186], ...     NaN     NaN
# 32382  [[PM2.5, , -, -], [PM10, , -, -], [NO2, , -, -...               -
# 32383  [[PM2.5, , -, -], [PM10, , -, -], [NO2, , -, -...               -
# 32384  [[PM2.5, , -, -], [PM10, , -, -], [NO2, , -, -...               -
# 32385  [[PM2.5, 67, 23, 120], [PM10, 95, 74, 111], [N...      18       7
# 32386  [[PM2.5, 78, 23, 290], [PM10, 102, 74, 164], [...      19       7
# 32387  [[PM2.5, 79, 23, 290], [PM10, 103, 74, 164], [...               -
# 32388  [[PM2.5, 79, 28, 157], [PM10, 142, 120, 179], ...      32      17
# 32389  [[PM2.5, 112, 27, 309], [PM10, 132, 99, 181], ...      33      17
# 32390  [[PM2.5, 98, 27, 217], [PM10, 132, 99, 179], [...      32      17
# 32391  [[PM2.5, 81, 27, 157], [PM10, 131, 99, 179], [...      31      17
# 32392  [[PM2.5, 79, 27, 157], [PM10, 132, 99, 179], [...      32      17
# 32393  [[PM2.5, 80, 27, 157], [PM10, 138, 107, 179], ...      32      17
# 32394  [[PM2.5, , -, -], [PM10, , -, -], [NO2, , -, -...               -
# 32395  [[PM2.5, 160, 33, 351], [PM10, 135, 100, 189],...      26      16
# 32396  [[PM2.5, , -, -], [PM10, , -, -], [NO2, , -, -...               -
# 32397  [[PM2.5, , -, -], [PM10, , -, -], [NO2, , -, -...               -
# 32398  [[PM2.5, , -, -], [PM10, , -, -], [NO2, , -, -...               -
# 32399  [[PM2.5, , -, -], [PM10, , -, -], [NO2, , -, -...               -
#
#       SO2_min                           Station   Time _avg _max _min
# 0          20              Alipur, Delhi - DPCC  20:00
# 1          21              Alipur, Delhi - DPCC   0:00
# 2          21              Alipur, Delhi - DPCC   4:00
# 3          19              Alipur, Delhi - DPCC   8:00
# 4          19              Alipur, Delhi - DPCC  12:00
# 5          20              Alipur, Delhi - DPCC  16:00
# 6          22         Anand Vihar, Delhi - DPCC  20:00
# 7          16         Anand Vihar, Delhi - DPCC   0:00
# 8          16         Anand Vihar, Delhi - DPCC   4:00
# 9          22         Anand Vihar, Delhi - DPCC   8:00
# 10         22         Anand Vihar, Delhi - DPCC  12:00
# 11         22         Anand Vihar, Delhi - DPCC  16:00
# 12         28         Ashok Vihar, Delhi - DPCC  20:00
# 13         22         Ashok Vihar, Delhi - DPCC   0:00
# 14         22         Ashok Vihar, Delhi - DPCC   4:00
# 15         22         Ashok Vihar, Delhi - DPCC   8:00
# 16         28         Ashok Vihar, Delhi - DPCC  12:00
# 17         28         Ashok Vihar, Delhi - DPCC  16:00
# 18        NaN            Aya Nagar, Delhi - IMD  20:00
# 19        NaN            Aya Nagar, Delhi - IMD   0:00
# 20        NaN            Aya Nagar, Delhi - IMD   4:00
# 21        NaN            Aya Nagar, Delhi - IMD   8:00
# 22        NaN            Aya Nagar, Delhi - IMD  12:00
# 23        NaN            Aya Nagar, Delhi - IMD  16:00
# 24         26              Bawana, Delhi - DPCC  20:00
# 25         29              Bawana, Delhi - DPCC   0:00
# 26         20              Bawana, Delhi - DPCC   4:00
# 27         20              Bawana, Delhi - DPCC   8:00
# 28         25              Bawana, Delhi - DPCC  12:00
# 29         26              Bawana, Delhi - DPCC  16:00
# ...       ...                               ...    ...  ...  ...  ...
# 32370      33            Sirifort, Delhi - CPCB  20:00
# 32371      32            Sirifort, Delhi - CPCB   0:00
# 32372      32            Sirifort, Delhi - CPCB   4:00
# 32373      33            Sirifort, Delhi - CPCB   8:00
# 32374      33            Sirifort, Delhi - CPCB  12:00
# 32375      33            Sirifort, Delhi - CPCB  16:00
# 32376     NaN         Sonia Vihar, Delhi - DPCC  20:00
# 32377     NaN         Sonia Vihar, Delhi - DPCC   0:00
# 32378     NaN         Sonia Vihar, Delhi - DPCC   4:00
# 32379     NaN         Sonia Vihar, Delhi - DPCC   8:00
# 32380     NaN         Sonia Vihar, Delhi - DPCC  12:00
# 32381     NaN         Sonia Vihar, Delhi - DPCC  16:00
# 32382       -  Sri Aurobindo Marg, Delhi - DPCC  20:00
# 32383       -  Sri Aurobindo Marg, Delhi - DPCC   0:00
# 32384       -  Sri Aurobindo Marg, Delhi - DPCC   4:00
# 32385      33  Sri Aurobindo Marg, Delhi - DPCC   8:00
# 32386      37  Sri Aurobindo Marg, Delhi - DPCC  12:00
# 32387       -  Sri Aurobindo Marg, Delhi - DPCC  16:00
# 32388      52         Vivek Vihar, Delhi - DPCC  20:00
# 32389      57         Vivek Vihar, Delhi - DPCC   0:00
# 32390      57         Vivek Vihar, Delhi - DPCC   4:00
# 32391      52         Vivek Vihar, Delhi - DPCC   8:00
# 32392      52         Vivek Vihar, Delhi - DPCC  12:00
# 32393      52         Vivek Vihar, Delhi - DPCC  16:00
# 32394       -            Wazirpur, Delhi - DPCC  20:00
# 32395      40            Wazirpur, Delhi - DPCC   0:00
# 32396       -            Wazirpur, Delhi - DPCC   4:00
# 32397       -            Wazirpur, Delhi - DPCC   8:00
# 32398       -            Wazirpur, Delhi - DPCC  12:00
# 32399       -            Wazirpur, Delhi - DPCC  16:00
#
# [32400 rows x 28 columns]

# %%
cols = ['PM2.5_avg','PM2.5_max','PM2.5_min','PM10_avg','PM10_max','PM10_min','NO2_avg', \
 	'NO2_max','NO2_min','NH3_avg','NH3_max','NH3_min','SO2_avg','SO2_max','SO2_min','CO_avg', \
    	'CO_max','CO_min','OZONE_avg','OZONE_max','OZONE_min']

df[cols] = df[cols].replace(to_replace=['','-',],value=np.nan)

df[cols] = df[cols].apply(pd.to_numeric)
df_nan = df[df[cols].isnull().all(axis=1)]
df_not_nan = df[~df[cols].isnull().all(axis=1)]
df_not_nan['Date'].value_counts().plot(kind='barh')
avg_cols = ['PM2.5_avg','NO2_avg','NH3_avg','SO2_avg','CO_avg','OZONE_avg',]
# df_not_nan[avg_cols] = df_not_nan[avg_cols].apply(pd.to_numeric)
df_not_nan['Aqi'] = df_not_nan[avg_cols].max(axis=1,skipna=True)
# df_not_nan['Aqi'] = df_not_nan[avg_cols].max(axis=1,skipna = True,numeric_only=True)
# df_not_nan.head()
# df_not_nan.drop(['Aqi'],axis=1)
# df_not_nan['Aqi'] = np.nanmax(df_not_nan[avg_cols])
df_not_nan
# df_not_nan.columns
df_not_nan.isna().sum()
# Out:
# /home/alpha/.local/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# CO_avg         818
# CO_max         824
# CO_min         824
# Date             0
# NH3_avg       7934
# NH3_max       7938
# NH3_min       7940
# NO2_avg       2692
# NO2_max       2696
# NO2_min       2698
# OZONE_avg     1928
# OZONE_max     1934
# OZONE_min     1934
# PM10_avg      5098
# PM10_max      5102
# PM10_min      5104
# PM2.5_avg     2716
# PM2.5_max     2720
# PM2.5_min     2722
# Pollutants       0
# SO2_avg       7242
# SO2_max       7246
# SO2_min       7248
# Station          0
# Time             0
# _avg             0
# _max             0
# _min             0
# Aqi              0
# dtype: int64

# %%
from collections import OrderedDict
time_grouped = df_not_nan.groupby(['Time'])

# for name,group in date_time_grouped:
#   print(name)
#   print(group)

aqi_by_time = {}
for name,group in time_grouped:
  aqi_means = {}
  # print(name)
  date_grouped = group.groupby(['Date'])
  # one_group = date_grouped.get_group('08/03/2020')
  # print(one_group['Aqi'].mean())
  # print(date_grouped.get_group('08/03/2020'))
  # print(date_grouped.first())
  for date,date_group in date_grouped:
    # aqi_means.append(date_group['Aqi'].mean())
    # print(date_group['Date'])
    
    aqi_means[date] = date_group['Aqi'].mean()

  # print(aqi_means)
  aqi_by_time[name] = aqi_means

# print(OrderedDict(aqi_by_time['0:00']))
# print(aqi_by_time['4:00'])
# print(aqi_by_time['8:00'])
# print(aqi_by_time['12:00'])
# print(aqi_by_time['16:00'])
# print(aqi_by_time['20:00'])

# %%
# !pip3 install ipympl
# # import ipympl
# %matplotlib widget
# %matplotlib notebook
# from ipywidgets import *
from datetime import datetime
import matplotlib.pyplot as plt

mydict = aqi_by_time['16:00']
# date_objects = [datetime.strptime(date,'%d/%m/%Y').date() for date in sorted(mydict)]
# values = [mydict[key] for key in sorted(mydict)]

date_objects,values = zip(*sorted(mydict.items()))

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(date_objects,values)
fig.autofmt_xdate()
plt.show()
# plt.plot(date_objects,values)
# plt.xticks(date_objects, values, rotation='vertical')
# Out:
# Collecting ipympl
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/4a/bc/c9258bc3346d156b232c13627e42c648ba75ef996a843a8a3bc9e8ca7320/ipympl-0.5.7-py2.py3-none-any.whl (463kB)
#     100% |████████████████████████████████| 471kB 2.0MB/s ta 0:00:01
# Collecting ipywidgets>=7.5.0 (from ipympl)
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/56/a0/dbcf5881bb2f51e8db678211907f16ea0a182b232c591a6d6f276985ca95/ipywidgets-7.5.1-py2.py3-none-any.whl (121kB)
#     100% |████████████████████████████████| 122kB 2.9MB/s ta 0:00:01
# Collecting ipykernel>=4.7 (from ipympl)
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/52/19/c2812690d8b340987eecd2cbc18549b1d130b94c5d97fcbe49f5f8710edf/ipykernel-5.3.4-py3-none-any.whl (120kB)
#     100% |████████████████████████████████| 122kB 5.0MB/s ta 0:00:01
# Collecting matplotlib>=2.0.0 (from ipympl)
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/96/a7/b6fa244fd8a8814ef9408c8a5a7e4ed0340e232a6f0ce2046b42e50672c0/matplotlib-3.3.1-cp36-cp36m-manylinux1_x86_64.whl (11.6MB)
#     100% |████████████████████████████████| 11.6MB 126kB/s eta 0:00:01
# Collecting nbformat>=4.2.0 (from ipywidgets>=7.5.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/4d/d1/b568bd35f95321f152f594b3647cd080e96d3347843ff2fa34dce871b8bf/nbformat-5.0.7-py3-none-any.whl (170kB)
#     100% |████████████████████████████████| 174kB 3.8MB/s eta 0:00:01
# Collecting traitlets>=4.3.1 (from ipywidgets>=7.5.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/ca/ab/872a23e29cec3cf2594af7e857f18b687ad21039c1f9b922fac5b9b142d5/traitlets-4.3.3-py2.py3-none-any.whl (75kB)
#     100% |████████████████████████████████| 81kB 4.0MB/s ta 0:00:01
# Collecting widgetsnbextension~=3.5.0 (from ipywidgets>=7.5.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/6c/7b/7ac231c20d2d33c445eaacf8a433f4e22c60677eb9776c7c5262d7ddee2d/widgetsnbextension-3.5.1-py2.py3-none-any.whl (2.2MB)
#     100% |████████████████████████████████| 2.2MB 602kB/s eta 0:00:01
# Collecting ipython>=4.0.0; python_version >= "3.3" (from ipywidgets>=7.5.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/23/6a/210816c943c9aeeb29e4e18a298f14bf0e118fe222a23e13bfcc2d41b0a4/ipython-7.16.1-py3-none-any.whl (785kB)
#     100% |████████████████████████████████| 788kB 1.3MB/s eta 0:00:01
# Collecting jupyter-client (from ipykernel>=4.7->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/48/2e/6d48ae4ef0c9aa1383b3186349472a01bb38dacb2162a4a4370525d3f2a4/jupyter_client-6.1.6-py3-none-any.whl (108kB)
#     100% |████████████████████████████████| 112kB 8.0MB/s eta 0:00:01
# Collecting tornado>=4.2 (from ipykernel>=4.7->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/95/84/119a46d494f008969bf0c775cb2c6b3579d3c4cc1bb1b41a022aa93ee242/tornado-6.0.4.tar.gz (496kB)
#     100% |████████████████████████████████| 501kB 1.6MB/s ta 0:00:011
# Collecting numpy>=1.15 (from matplotlib>=2.0.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/22/e7/4b2bdddb99f5f631d8c1de259897c2b7d65dcfcc1e0a6fd17a7f62923500/numpy-1.19.1-cp36-cp36m-manylinux1_x86_64.whl (13.4MB)
#     100% |████████████████████████████████| 13.4MB 100kB/s eta 0:00:01
# Collecting pillow>=6.2.0 (from matplotlib>=2.0.0->ipympl)
#   Using cached https://files.pythonhosted.org/packages/30/bf/92385b4262178ca22b34f82e0e09c2922eb351fe39f3cc7b8ba9ea555b41/Pillow-7.2.0-cp36-cp36m-manylinux1_x86_64.whl
# Collecting kiwisolver>=1.0.1 (from matplotlib>=2.0.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/ae/23/147de658aabbf968324551ea22c0c13a00284c4ef49a77002e91f79657b7/kiwisolver-1.2.0-cp36-cp36m-manylinux1_x86_64.whl (88kB)
#     100% |████████████████████████████████| 92kB 2.5MB/s eta 0:00:01
# Collecting cycler>=0.10 (from matplotlib>=2.0.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Using cached https://files.pythonhosted.org/packages/f7/d2/e07d3ebb2bd7af696440ce7e754c59dd546ffe1bbe732c8ab68b9c834e61/cycler-0.10.0-py2.py3-none-any.whl
# Collecting certifi>=2020.06.20 (from matplotlib>=2.0.0->ipympl)
#   Using cached https://files.pythonhosted.org/packages/5e/c4/6c4fe722df5343c33226f0b4e0bb042e4dc13483228b4718baf286f86d87/certifi-2020.6.20-py2.py3-none-any.whl
# Collecting python-dateutil>=2.1 (from matplotlib>=2.0.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/d4/70/d60450c3dd48ef87586924207ae8907090de0b306af2bce5d134d78615cb/python_dateutil-2.8.1-py2.py3-none-any.whl (227kB)
#     100% |████████████████████████████████| 235kB 3.0MB/s ta 0:00:011
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3 (from matplotlib>=2.0.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/8a/bb/488841f56197b13700afd5658fc279a2025a39e22449b7cf29864669b15d/pyparsing-2.4.7-py2.py3-none-any.whl (67kB)
#     100% |████████████████████████████████| 71kB 5.6MB/s eta 0:00:01
# Collecting ipython-genutils (from nbformat>=4.2.0->ipywidgets>=7.5.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Using cached https://files.pythonhosted.org/packages/fa/bc/9bd3b5c2b4774d5f33b2d544f1460be9df7df2fe42f352135381c347c69a/ipython_genutils-0.2.0-py2.py3-none-any.whl
# Collecting jupyter-core (from nbformat>=4.2.0->ipywidgets>=7.5.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/63/0d/df2d17cdf389cea83e2efa9a4d32f7d527ba78667e0153a8e676e957b2f7/jupyter_core-4.6.3-py2.py3-none-any.whl (83kB)
#     100% |████████████████████████████████| 92kB 3.3MB/s ta 0:00:01
# Collecting jsonschema!=2.5.0,>=2.4 (from nbformat>=4.2.0->ipywidgets>=7.5.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/c5/8f/51e89ce52a085483359217bc72cdbf6e75ee595d5b1d4b5ade40c7e018b8/jsonschema-3.2.0-py2.py3-none-any.whl (56kB)
#     100% |████████████████████████████████| 61kB 5.3MB/s eta 0:00:01
# Collecting decorator (from traitlets>=4.3.1->ipywidgets>=7.5.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/ed/1b/72a1821152d07cf1d8b6fce298aeb06a7eb90f4d6d41acec9861e7cc6df0/decorator-4.4.2-py2.py3-none-any.whl
# Collecting six (from traitlets>=4.3.1->ipywidgets>=7.5.0->ipympl)
#   Using cached https://files.pythonhosted.org/packages/ee/ff/48bde5c0f013094d729fe4b0316ba2a24774b3ff1c52d924a8a4cb04078a/six-1.15.0-py2.py3-none-any.whl
# Collecting notebook>=4.4.1 (from widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/ea/00/1be79c61e2dfedb29c430b0e08f9fd2cb6ee4f6be92ba6f185dd6bb00052/notebook-6.1.3-py3-none-any.whl (9.4MB)
#     100% |████████████████████████████████| 9.4MB 164kB/s ta 0:00:011
# Collecting backcall (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.0->ipympl)
#   Downloading https://files.pythonhosted.org/packages/4c/1c/ff6546b6c12603d8dd1070aa3c3d273ad4c07f5771689a7b69a550e8c951/backcall-0.2.0-py2.py3-none-any.whl
# Collecting pygments (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/2d/68/106af3ae51daf807e9cdcba6a90e518954eb8b70341cee52995540a53ead/Pygments-2.6.1-py3-none-any.whl (914kB)
#     100% |████████████████████████████████| 921kB 1.3MB/s eta 0:00:01
# Collecting pexpect; sys_platform != "win32" (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/39/7b/88dbb785881c28a102619d46423cb853b46dbccc70d3ac362d99773a78ce/pexpect-4.8.0-py2.py3-none-any.whl (59kB)
#     100% |████████████████████████████████| 61kB 3.1MB/s ta 0:00:01
# Collecting prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/72/65/a3ef98b56d57a6d0a04cea5810ecbf3700a225d296ca298b3442dddebb42/prompt_toolkit-3.0.6-py3-none-any.whl (354kB)
#     100% |████████████████████████████████| 358kB 3.6MB/s eta 0:00:01
# Collecting jedi>=0.10 (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.0->ipympl)
#   Downloading https://files.pythonhosted.org/packages/c3/d4/36136b18daae06ad798966735f6c3fb96869c1be9f8245d2a8f556e40c36/jedi-0.17.2-py2.py3-none-any.whl (1.4MB)
#     100% |████████████████████████████████| 1.4MB 841kB/s eta 0:00:01
# Collecting pickleshare (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Using cached https://files.pythonhosted.org/packages/9a/41/220f49aaea88bc6fa6cba8d05ecf24676326156c23b991e80b3f2fc24c77/pickleshare-0.7.5-py2.py3-none-any.whl
# Collecting setuptools>=18.5 (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/c3/a9/5dc32465951cf4812e9e93b4ad2d314893c2fa6d5f66ce5c057af6e76d85/setuptools-49.6.0-py3-none-any.whl (803kB)
#     100% |████████████████████████████████| 808kB 1.3MB/s eta 0:00:01
# Collecting pyzmq>=13 (from jupyter-client->ipykernel>=4.7->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/56/ff/34bf45e5cf8367edcf4946b26690f0982b3ec701b0a655edfe562d29e246/pyzmq-19.0.2-cp36-cp36m-manylinux1_x86_64.whl (1.1MB)
#     100% |████████████████████████████████| 1.1MB 1.1MB/s eta 0:00:01
# Collecting attrs>=17.4.0 (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Using cached https://files.pythonhosted.org/packages/a2/db/4313ab3be961f7a763066401fb77f7748373b6094076ae2bda2806988af6/attrs-19.3.0-py2.py3-none-any.whl
# Collecting importlib-metadata; python_version < "3.8" (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/8e/58/cdea07eb51fc2b906db0968a94700866fc46249bdc75cac23f9d13168929/importlib_metadata-1.7.0-py2.py3-none-any.whl
# Collecting pyrsistent>=0.14.0 (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/9f/0d/cbca4d0bbc5671822a59f270e4ce3f2195f8a899c97d0d5abb81b191efb5/pyrsistent-0.16.0.tar.gz (108kB)
#     100% |████████████████████████████████| 112kB 5.2MB/s eta 0:00:01
# Collecting jinja2 (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/30/9e/f663a2aa66a09d838042ae1a2c5659828bb9b41ea3a6efa20a20fd92b121/Jinja2-2.11.2-py2.py3-none-any.whl (125kB)
#     100% |████████████████████████████████| 133kB 5.5MB/s eta 0:00:01
# Collecting Send2Trash (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Using cached https://files.pythonhosted.org/packages/49/46/c3dc27481d1cc57b9385aff41c474ceb7714f7935b1247194adae45db714/Send2Trash-1.5.0-py3-none-any.whl
# Collecting terminado>=0.8.3 (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/ff/96/1d9a2c23990aea8f8e0b5c3b6627d03196a73771a17a2d9860bbe9823ab6/terminado-0.8.3-py2.py3-none-any.whl
# Collecting prometheus-client (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/3f/0e/554a265ffdc56e1494ef08e18f765b0cdec78797f510c58c45cf37abb4f4/prometheus_client-0.8.0-py2.py3-none-any.whl (53kB)
#     100% |████████████████████████████████| 61kB 6.1MB/s eta 0:00:01
# Collecting nbconvert (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/79/6c/05a569e9f703d18aacb89b7ad6075b404e8a4afde2c26b73ca77bb644b14/nbconvert-5.6.1-py2.py3-none-any.whl (455kB)
#     100% |████████████████████████████████| 460kB 1.9MB/s ta 0:00:011
# Collecting argon2-cffi (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->ipympl)
#   Downloading https://files.pythonhosted.org/packages/e0/d7/5da06217807106ed6d7b4f5ccb8ec5e3f9ec969217faad4b5d1af0b55101/argon2_cffi-20.1.0-cp35-abi3-manylinux1_x86_64.whl (97kB)
#     100% |████████████████████████████████| 102kB 5.7MB/s ta 0:00:01
# Collecting ptyprocess>=0.5 (from pexpect; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Using cached https://files.pythonhosted.org/packages/d1/29/605c2cc68a9992d18dada28206eeada56ea4bd07a239669da41674648b6f/ptyprocess-0.6.0-py2.py3-none-any.whl
# Collecting wcwidth (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/59/7c/e39aca596badaf1b78e8f547c807b04dae603a433d3e7a7e04d67f2ef3e5/wcwidth-0.2.5-py2.py3-none-any.whl
# Collecting parso<0.8.0,>=0.7.0 (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.0->ipympl)
#   Downloading https://files.pythonhosted.org/packages/93/d1/e635bdde32890db5aeb2ffbde17e74f68986305a4466b0aa373b861e3f00/parso-0.7.1-py2.py3-none-any.whl (109kB)
#     100% |████████████████████████████████| 112kB 6.2MB/s ta 0:00:01
# Collecting zipp>=0.5 (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/b2/34/bfcb43cc0ba81f527bc4f40ef41ba2ff4080e047acb0586b56b3d017ace4/zipp-3.1.0-py3-none-any.whl
# Collecting MarkupSafe>=0.23 (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Using cached https://files.pythonhosted.org/packages/b2/5f/23e0023be6bb885d00ffbefad2942bc51a620328ee910f64abe5a8d18dd1/MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl
# Collecting mistune<2,>=0.8.1 (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Using cached https://files.pythonhosted.org/packages/09/ec/4b43dae793655b7d8a25f76119624350b4d65eb663459eb9603d7f1f0345/mistune-0.8.4-py2.py3-none-any.whl
# Collecting testpath (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/1b/9e/1a170feaa54f22aeb5a5d16c9015e82234275a3c8ab630b552493f9cb8a9/testpath-0.4.4-py2.py3-none-any.whl (163kB)
#     100% |████████████████████████████████| 174kB 3.5MB/s eta 0:00:01
# Collecting defusedxml (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Using cached https://files.pythonhosted.org/packages/06/74/9b387472866358ebc08732de3da6dc48e44b0aacd2ddaa5cb85ab7e986a2/defusedxml-0.6.0-py2.py3-none-any.whl
# Collecting pandocfilters>=1.4.1 (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->ipympl)
#   Cache entry deserialization failed, entry ignored
# Collecting bleach (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/9a/1e/7d6cb3b27cd2c490558349ca5d5cc05b390b017da1c704cac807ac8bd9fb/bleach-3.1.5-py2.py3-none-any.whl (151kB)
#     100% |████████████████████████████████| 153kB 3.4MB/s eta 0:00:01
# Collecting entrypoints>=0.2.2 (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Using cached https://files.pythonhosted.org/packages/ac/c6/44694103f8c221443ee6b0041f69e2740d89a25641e62fb4f2ee568f2f9c/entrypoints-0.3-py2.py3-none-any.whl
# Collecting cffi>=1.0.0 (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/eb/9c/c6b452e414ea289822f3cc44bdf4822066dc7b947f03eaa2a2b97dda5032/cffi-1.14.1-cp36-cp36m-manylinux1_x86_64.whl (400kB)
#     100% |████████████████████████████████| 409kB 2.5MB/s eta 0:00:01
# Collecting webencodings (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->ipympl)
#   Using cached https://files.pythonhosted.org/packages/f4/24/2a3e3df732393fed8b3ebf2ec078f05546de641fe1b667ee316ec1dcf3b7/webencodings-0.5.1-py2.py3-none-any.whl
# Collecting packaging (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/46/19/c5ab91b1b05cfe63cccd5cfc971db9214c6dd6ced54e33c30d5af1d2bc43/packaging-20.4-py2.py3-none-any.whl
# Collecting pycparser (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->ipympl)
#   Cache entry deserialization failed, entry ignored
#   Using cached https://files.pythonhosted.org/packages/ae/e7/d9c3a176ca4b02024debf82342dab36efadfc5776f9c8db077e8f6e71821/pycparser-2.20-py2.py3-none-any.whl
# Building wheels for collected packages: tornado, pyrsistent
#   Running setup.py bdist_wheel for tornado ... done
#   Stored in directory: /home/alpha/.cache/pip/wheels/93/84/2f/409c7b2bb3afc3aa727f7ee8787975e0793f74d1165f4d0104
#   Running setup.py bdist_wheel for pyrsistent ... done
#   Stored in directory: /home/alpha/.cache/pip/wheels/c2/85/ad/bc6d41e2c4b35c9fdfed48f0fcd411ffc4164e67755ddf9ebb
# Successfully built tornado pyrsistent
# Installing collected packages: pyzmq, tornado, six, python-dateutil, ipython-genutils, decorator, traitlets, jupyter-core, jupyter-client, backcall, pygments, ptyprocess, pexpect, wcwidth, prompt-toolkit, parso, jedi, pickleshare, setuptools, ipython, ipykernel, attrs, zipp, importlib-metadata, pyrsistent, jsonschema, nbformat, MarkupSafe, jinja2, Send2Trash, terminado, prometheus-client, mistune, testpath, defusedxml, pandocfilters, webencodings, pyparsing, packaging, bleach, entrypoints, nbconvert, pycparser, cffi, argon2-cffi, notebook, widgetsnbextension, ipywidgets, numpy, pillow, kiwisolver, cycler, certifi, matplotlib, ipympl
# Segmentation fault (core dumped)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-75dbe691347a> in <module>()
#       7 import matplotlib.pyplot as plt
#       8
# ----> 9 mydict = aqi_by_time['16:00']
#      10 # date_objects = [datetime.strptime(date,'%d/%m/%Y').date() for date in sorted(mydict)]
#      11 # values = [mydict[key] for key in sorted(mydict)]
#
# NameError: name 'aqi_by_time' is not defined
